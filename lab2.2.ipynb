# %%
import numpy as np
import matplotlib.pyplot as plt

# Given values
A1 = np.array([[0.05], [0.10]])
W2 = np.array([[0.15, 0.20], [0.25, 0.30]])
W3 = np.array([[0.40, 0.45], [0.50, 0.55]])
b2 = np.array([[0.35], [0.35]])
b3 = np.array([[0.60], [0.60]])

# Given R vector
R = np.array([[0.01], [0.99]])

# Learning rate
alpha = 1

# Sigmoid activation function and its derivative
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

# Number of epochs
epochs = 20

# Initialize an array to store total errors
errors = np.zeros(epochs)

# Loop through epochs
for epoch in range(epochs):
    # Forward pass calculations
    Z2 = np.dot(W2, A1) + b2
    A2 = sigmoid(Z2)

    Z3 = np.dot(W3, A2) + b3
    A3 = sigmoid(Z3)

    # Calculate Deltas
    D3 = (A3 - R) * sigmoid_derivative(Z3)
    D2 = np.dot(W3.T, D3) * sigmoid_derivative(Z2)

    # Calculate gradients
    grad_W3 = np.dot(D3, A2.T)
    grad_b3 = D3
    grad_W2 = np.dot(D2, A1.T)
    grad_b2 = D2

    # Update weights and biases
    W2 = W2 - alpha * grad_W2
    b2 = b2 - alpha * grad_b2

    W3 = W3 - alpha * grad_W3
    b3 = b3 - alpha * grad_b3

    # Calculate total error and store in array
    total_error = np.sum((A3 - R) ** 2) / 2
    errors[epoch] = total_error

    # Print values for each epoch
    print(f"Epoch {epoch + 1}:")
    print("A2:", A2)
    print("A3:", A3)
    print("Z2:", Z2)
    print("Z3:", Z3)
    print("D2:", D2)
    print("D3:", D3)
    print("W2:", W2)
    print("W3:", W3)
    print("b2:", b2)
    print("b3:", b3)
    print("-" * 40)

# Plot the graph of total errors
plt.figure()
plt.plot(range(1, epochs + 1), errors, '-o')
plt.xlabel('Epochs')
plt.ylabel('Total Error')
plt.title('Total Error vs. Epochs')
plt.grid(True)
plt.show()
# Out:
# Epoch 1:
# A2: [[0.59326999]
#  [0.59688438]]
# A3: [[0.75136507]
#  [0.77292847]]
# Z2: [[0.3775]
#  [0.3925]]
# Z3: [[1.10590597]
#  [1.2249214 ]]
# D2: [[0.00877135]
#  [0.00995425]]
# D3: [[ 0.13849856]
#  [-0.03809824]]
# W2: [[0.14956143 0.19912286]
#  [0.24950229 0.29900457]]
# W3: [[0.31783296 0.36733237]
#  [0.52260254 0.57274024]]
# b2: [[0.34122865]
#  [0.34004575]]
# b3: [[0.46150144]
#  [0.63809824]]
# ----------------------------------------
# Epoch 2:
# A2: [[0.59112524]
#  [0.59445696]]
# A3: [[0.70427601]
#  [0.78372225]]
# Z2: [[0.368619  ]
#  [0.38242132]]
# Z3: [[0.86774381]
#  [1.28749121]]
# D2: [[0.00669147]
#  [0.00797725]]
# D3: [[ 0.14459777]
#  [-0.03496443]]
# W2: [[0.14922686 0.19845372]
#  [0.24910342 0.29820685]]
# W3: [[0.23235757 0.28137522]
#  [0.5432709  0.59352509]]
# b2: [[0.33453718]
#  [0.3320685 ]]
# b3: [[0.31690366]
#  [0.67306266]]
# ----------------------------------------
# Epoch 3:
# A2: [[0.58948672]
#  [0.59250831]]
# A3: [[0.6503533 ]
#  [0.79330807]]
# Z2: [[0.36184389]
#  [0.37434436]]
# Z3: [[0.62059252]
#  [1.34498219]]
# D2: [[0.00394756]
#  [0.00527058]]
# D3: [[ 0.14561242]
#  [-0.03225165]]
# W2: [[0.14902948 0.19805896]
#  [0.2488399  0.29767979]]
# W3: [[0.14652098 0.19509865]
#  [0.56228282 0.61263446]]
# b2: [[0.33058962]
#  [0.32679792]]
# b3: [[0.17129124]
#  [0.70531431]]
# ----------------------------------------
# Epoch 4:
# A2: [[0.58851915]
#  [0.59121923]]
# A3: [[0.59215174]
#  [0.8019346 ]]
# Z2: [[0.35784699]
#  [0.3690079 ]]
# Z3: [[0.37286771]
#  [1.39842979]]
# D2: [[0.00092115]
#  [0.0022064 ]]
# D3: [[ 0.14059433]
#  [-0.02987146]]
# W2: [[0.14898342 0.19796685]
#  [0.24872958 0.29745915]]
# W3: [[0.06377852 0.11197657]
#  [0.57986274 0.63029504]]
# b2: [[0.32966847]
#  [0.32459152]]
# b3: [[0.0306969 ]
#  [0.73518577]]
# ----------------------------------------
# Epoch 5:
# A2: [[0.58829328]
#  [0.59067921]]
# A3: [[0.53353946]
#  [0.80978554]]
# Z2: [[0.35691433]
#  [0.36677391]]
# Z3: [[0.13435961]
#  [1.44861731]]
# D2: [[-0.00188588]
#  [-0.00070266]]
# D3: [[ 0.13029594]
#  [-0.02775896]]
# W2: [[0.14907772 0.19815543]
#  [0.24876471 0.29752942]]
# W3: [[-0.01287371  0.03501347]
#  [ 0.59619315  0.64669168]]
# b2: [[0.33155435]
#  [0.32529418]]
# b3: [[-0.09959903]
#  [ 0.76294473]]
# ----------------------------------------
# Epoch 6:
# A2: [[0.58875567]
#  [0.59085121]]
# A3: [[0.47839078]
#  [0.81698542]]
# Z2: [[0.35882378]
#  [0.36748536]]
# Z3: [[-0.08649075]
#  [ 1.4960554 ]]
# D2: [[-0.00409857]
#  [-0.00305496]]
# D3: [[ 0.11687898]
#  [-0.02586918]]
# W2: [[0.14928265 0.19856529]
#  [0.24891746 0.29783491]]
# W3: [[-0.08168687 -0.03404461]
#  [ 0.61142378  0.66197652]]
# b2: [[0.33565292]
#  [0.32834914]]
# b3: [[-0.21647801]
#  [ 0.78881392]]
# ----------------------------------------
# Epoch 7:
# A2: [[0.58976006]
#  [0.59159876]]
# A3: [[0.42927876]
#  [0.82361466]]
# Z2: [[0.36297358]
#  [0.3705785 ]]
# Z3: [[-0.28479442]
#  [ 1.54103173]]
# D2: [[-0.00560584]
#  [-0.00471092]]
# D3: [[ 0.10272267]
#  [-0.02417139]]
# W2: [[0.14956294 0.19912588]
#  [0.249153   0.29830601]]
# W3: [[-0.1422686  -0.09481522]
#  [ 0.6256791   0.67627628]]
# b2: [[0.34125876]
#  [0.33306005]]
# b3: [[-0.31920068]
#  [ 0.81298531]]
# ----------------------------------------
# Epoch 8:
# A2: [[0.59113261]
#  [0.59275068]]
# A3: [[0.38710395]
#  [0.829729  ]]
# Z2: [[0.36864949]
#  [0.3753483 ]]
# Z3: [[-0.45950207]
#  [ 1.58370785]]
# D2: [[-0.0065006 ]
#  [-0.00574427]]
# D3: [[ 0.0894696 ]
#  [-0.02264289]]
# W2: [[0.14988797 0.19977594]
#  [0.24944022 0.29888043]]
# W3: [[-0.195157   -0.14784839]
#  [ 0.63906405  0.68969787]]
# b2: [[0.34775936]
#  [0.33880433]]
# b3: [[-0.40867028]
#  [ 0.8356282 ]]
# ----------------------------------------
# Epoch 9:
# A2: [[0.59272245]
#  [0.59415391]]
# A3: [[0.35156004]
#  [0.83537389]]
# Z2: [[0.37523135]
#  [0.38116438]]
# Z3: [[-0.61218891]
#  [ 1.6242025 ]]
# D2: [[-0.00694884]
#  [-0.00631253]]
# D3: [[ 0.07786393]
#  [-0.02126486]]
# W2: [[0.15023541 0.20047082]
#  [0.24975584 0.29951169]]
# W3: [[-0.2413087  -0.19411155]
#  [ 0.65166821  0.70233247]]
# b2: [[0.3547082 ]
#  [0.34511685]]
# b3: [[-0.48653421]
#  [ 0.85689305]]
# ----------------------------------------
# Epoch 10:
# A2: [[0.59441977]
#  [0.59569417]]
# A3: [[0.32177992]
#  [0.84059112]]
# Z2: [[0.38226706]
#  [0.38755581]]
# Z3: [[-0.74560399]
#  [ 1.66263288]]
# D2: [[-0.00710377]
#  [-0.00656748]]
# D3: [[ 0.0680421 ]
#  [-0.02002044]]
# W2: [[0.1505906  0.2011812 ]
#  [0.25008422 0.30016843]]
# W3: [[-0.28175427 -0.23464383]
#  [ 0.66356876  0.71425853]]
# b2: [[0.36181197]
#  [0.35168433]]
# b3: [[-0.55457632]
#  [ 0.8769135 ]]
# ----------------------------------------
# Epoch 11:
# A2: [[0.59615261]
#  [0.59729465]]
# A3: [[0.29677631]
#  [0.84542036]]
# Z2: [[0.38945962]
#  [0.39420539]]
# Z3: [[-0.86269636]
#  [ 1.69912454]]
# D2: [[-0.00707837]
#  [-0.00662405]]
# D3: [[ 0.05985025]
#  [-0.01889436]]
# W2: [[0.15094452 0.20188903]
#  [0.25041542 0.30083084]]
# W3: [[-0.31743415 -0.27039207]
#  [ 0.67483268  0.72554403]]
# b2: [[0.36889034]
#  [0.35830838]]
# b3: [[-0.61442657]
#  [ 0.89580786]]
# ----------------------------------------
# Epoch 12:
# A2: [[0.59787686]
#  [0.59890681]]
# A3: [[0.275648  ]
#  [0.84989885]]
# Z2: [[0.39662647]
#  [0.40091224]]
# Z3: [[-0.96615276]
#  [ 1.73380797]]
# D2: [[-0.0069477 ]
#  [-0.00656018]]
# D3: [[ 0.05304092]
#  [-0.01787281]]
# W2: [[0.1512919  0.2025838 ]
#  [0.25074343 0.30148686]]
# W3: [[-0.34914609 -0.30215864]
#  [ 0.68551842  0.73624818]]
# b2: [[0.37583804]
#  [0.36486857]]
# b3: [[-0.66746749]
#  [ 0.91368067]]
# ----------------------------------------
# Epoch 13:
# A2: [[0.59956694]
#  [0.60050133]]
# A3: [[0.25764391]
#  [0.85406087]]
# Z2: [[0.40366102]
#  [0.40755442]]
# Z3: [[-1.05825061]
#  [ 1.76681287]]
# D2: [[-0.00675904]
#  [-0.00642607]]
# D3: [[ 0.04736525]
#  [-0.01694358]]
# W2: [[0.15162985 0.20325971]
#  [0.25106473 0.30212946]]
# W3: [[-0.37754473 -0.33060153]
#  [ 0.69567723  0.74642282]]
# b2: [[0.38259708]
#  [0.37129463]]
# b3: [[-0.71483274]
#  [ 0.93062425]]
# ----------------------------------------
# Epoch 14:
# A2: [[0.60120885]
#  [0.60206119]]
# A3: [[0.24216281]
#  [0.85793745]]
# Z2: [[0.41050455]
#  [0.41406081]]
# Z3: [[-1.14085832]
#  [ 1.79826376]]
# D2: [[-0.00654138]
#  [-0.00625316]]
# D3: [[ 0.04260651]
#  [-0.01609589]]
# W2: [[0.15195692 0.20391385]
#  [0.25137739 0.30275478]]
# W3: [[-0.40316014 -0.35625326]
#  [ 0.70535422  0.75611353]]
# b2: [[0.38913846]
#  [0.37754779]]
# b3: [[-0.75743925]
#  [ 0.94672013]]
# ----------------------------------------
# Epoch 15:
# A2: [[0.60279573]
#  [0.60357708]]
# A3: [[0.22873132]
#  [0.86155639]]
# Z2: [[0.41712769]
#  [0.42039214]]
# Z3: [[-1.21548877]
#  [ 1.82827744]]
# D2: [[-0.00631219]
#  [-0.00606093]]
# D3: [[ 0.03858711]
#  [-0.01532036]]
# W2: [[0.15227253 0.20454507]
#  [0.25168044 0.30336087]]
# W3: [[-0.42642029 -0.37954356]
#  [ 0.71458927  0.76536055]]
# b2: [[0.39545065]
#  [0.38360872]]
# b3: [[-0.79602637]
#  [ 0.9620405 ]]
# ----------------------------------------
# Epoch 16:
# A2: [[0.60432496]
#  [0.60504448]]
# A3: [[0.21697822]
#  [0.86494243]]
# Z2: [[0.42351879]
#  [0.42652882]]
# Z3: [[-1.28336352]
#  [ 1.8569618 ]]
# D2: [[-0.00608181]
#  [-0.0058613 ]]
# D3: [[ 0.03516533]
#  [-0.01460885]]
# W2: [[0.15257662 0.20515325]
#  [0.2519735  0.303947  ]]
# W3: [[-0.44767157 -0.40082014]
#  [ 0.72341776  0.77419956]]
# b2: [[0.40153247]
#  [0.38947002]]
# b3: [[-0.83119169]
#  [ 0.97664935]]
# ----------------------------------------
# Epoch 17:
# A2: [[0.60579645]
#  [0.60646175]]
# A3: [[0.20661169]
#  [0.8681175 ]]
# Z2: [[0.42967662]
#  [0.4324634 ]]
# Z3: [[-1.34547163]
#  [ 1.88441568]]
# D2: [[-0.00585624]
#  [-0.00566152]]
# D3: [[ 0.03222924]
#  [-0.01395427]]
# W2: [[0.15286944 0.20573887]
#  [0.25225658 0.30451315]]
# W3: [[-0.46719593 -0.42036594]
#  [ 0.73187121  0.78266229]]
# b2: [[0.4073887 ]
#  [0.39513154]]
# b3: [[-0.86342093]
#  [ 0.99060362]]
# ----------------------------------------
# Epoch 18:
# A2: [[0.60721155]
#  [0.60782901]]
# A3: [[0.19740095]
#  [0.87110104]]
# Z2: [[0.43560606]
#  [0.43819568]]
# Z3: [[-1.40261831]
#  [ 1.91072911]]
# D2: [[-0.00563879]
#  [-0.00546585]]
# D3: [[ 0.02969065]
#  [-0.01335045]]
# W2: [[0.15315137 0.20630275]
#  [0.25252987 0.30505974]]
# W3: [[-0.48522443 -0.43841278]
#  [ 0.73997776  0.79077708]]
# b2: [[0.41302749]
#  [0.40059739]]
# b3: [[-0.89311158]
#  [ 1.00395407]]
# ----------------------------------------
# Epoch 19:
# A2: [[0.6085724 ]
#  [0.60914742]]
# A3: [[0.18916211]
#  [0.87391027]]
# Z2: [[0.44131534]
#  [0.44372986]]
# Z3: [[-1.45546379]
#  [ 1.93598393]]
# D2: [[-0.00543117]
#  [-0.00527676]]
# D3: [[ 0.02747985]
#  [-0.01279206]]
# W2: [[0.15342293 0.20684587]
#  [0.25279371 0.30558742]]
# W3: [[-0.50194791 -0.45515206]
#  [ 0.74776265  0.79856933]]
# b2: [[0.41845866]
#  [0.40587415]]
# b3: [[-0.92059143]
#  [ 1.01674613]]
# ----------------------------------------
# Epoch 20:
# A2: [[0.60988156]
#  [0.61041871]]
# A3: [[0.18174736]
#  [0.87656049]]
# Z2: [[0.4468144 ]
#  [0.44907258]]
# Z3: [[-1.50455354]
#  [ 1.96025444]]
# D2: [[-0.00523409]
#  [-0.00509556]]
# D3: [[ 0.02554145]
#  [-0.01227441]]
# W2: [[0.15368464 0.20736928]
#  [0.25304849 0.30609697]]
# W3: [[-0.51752517 -0.47074304]
#  [ 0.75524858  0.80606185]]
# b2: [[0.42369276]
#  [0.41096971]]
# b3: [[-0.94613288]
#  [ 1.02902053]]
# ----------------------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given values
A1 = np.array([[0.05], [0.10]])
W2 = np.array([[0.15, 0.20], [0.25, 0.30]])
W3 = np.array([[0.40, 0.45], [0.50, 0.55]])
b2 = np.array([[0.35], [0.35]])
b3 = np.array([[0.60], [0.60]])

# Given R vector
R = np.array([[0.01], [0.99]])

# Learning rate
alpha = 2

# Sigmoid activation function and its derivative
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

# Number of epochs
epochs = 10

# Initialize an array to store total errors
errors = np.zeros(epochs)

# Loop through epochs
for epoch in range(epochs):
    # Forward pass calculations
    Z2 = np.dot(W2, A1) + b2
    A2 = sigmoid(Z2)

    Z3 = np.dot(W3, A2) + b3
    A3 = sigmoid(Z3)

    # Calculate Deltas
    D3 = (A3 - R) * sigmoid_derivative(Z3)
    D2 = np.dot(W3.T, D3) * sigmoid_derivative(Z2)

    # Calculate gradients
    grad_W3 = np.dot(D3, A2.T)
    grad_b3 = D3
    grad_W2 = np.dot(D2, A1.T)
    grad_b2 = D2

    # Update weights and biases
    W2 = W2 - alpha * grad_W2
    b2 = b2 - alpha * grad_b2

    W3 = W3 - alpha * grad_W3
    b3 = b3 - alpha * grad_b3

    # Calculate total error and store in array
    total_error = np.sum((A3 - R) ** 2) / 2
    errors[epoch] = total_error

    # Print values for each epoch
    print(f"Epoch {epoch + 1}:")
    print("A2:", A2)
    print("A3:", A3)
    print("Z2:", Z2)
    print("Z3:", Z3)
    print("D2:", D2)
    print("D3:", D3)
    print("W2:", W2)
    print("W3:", W3)
    print("b2:", b2)
    print("b3:", b3)
    print("-" * 40)

# Plot the graph of total errors
plt.figure()
plt.plot(range(1, epochs + 1), errors, '-o')
plt.xlabel('Epochs')
plt.ylabel('Total Error')
plt.title('Total Error vs. Epochs')
plt.grid(True)
plt.show()
# Out:
# Epoch 1:
# A2: [[0.59326999]
#  [0.59688438]]
# A3: [[0.75136507]
#  [0.77292847]]
# Z2: [[0.3775]
#  [0.3925]]
# Z3: [[1.10590597]
#  [1.2249214 ]]
# D2: [[0.00877135]
#  [0.00995425]]
# D3: [[ 0.13849856]
#  [-0.03809824]]
# W2: [[0.14912286 0.19824573]
#  [0.24900457 0.29800915]]
# W3: [[0.23566592 0.28466474]
#  [0.54520508 0.59548048]]
# b2: [[0.33245729]
#  [0.33009149]]
# b3: [[0.32300288]
#  [0.67619647]]
# ----------------------------------------
# Epoch 2:
# A2: [[0.58897701]
#  [0.59202492]]
# A3: [[0.65256503]
#  [0.79410494]]
# Z2: [[0.35973801]
#  [0.37234263]]
# Z3: [[0.63033331]
#  [1.34984902]]
# D2: [[0.00408404]
#  [0.00540995]]
# D3: [[ 0.14568486]
#  [-0.03202929]]
# W2: [[0.14871446 0.19742892]
#  [0.24846358 0.29692716]]
# W3: [[0.06405586 0.11216661]
#  [0.58293411 0.63340476]]
# b2: [[0.3242892]
#  [0.3192716]]
# b3: [[0.03163316]
#  [0.74025505]]
# ----------------------------------------
# Epoch 3:
# A2: [[0.58697348]
#  [0.58937626]]
# A3: [[0.5337836 ]
#  [0.81087959]]
# Z2: [[0.35146782]
#  [0.36138749]]
# Z3: [[0.13534059]
#  [1.45573564]]
# D2: [[-0.00185777]
#  [-0.00067235]]
# D3: [[ 0.13034809]
#  [-0.02746881]]
# W2: [[0.14890024 0.19780047]
#  [0.24853081 0.29706163]]
# W3: [[-0.08896589 -0.04148153]
#  [ 0.61518104  0.66578369]]
# b2: [[0.32800474]
#  [0.3206163 ]]
# b3: [[-0.22906301]
#  [ 0.79519267]]
# ----------------------------------------
# Epoch 4:
# A2: [[0.58788522]
#  [0.58970573]]
# A3: [[0.42413374]
#  [0.82483644]]
# Z2: [[0.3552298]
#  [0.362749 ]]
# Z3: [[-0.30582664]
#  [ 1.54946496]]
# D2: [[-0.00573685]
#  [-0.00485925]]
# D3: [[ 0.10114981]
#  [-0.02386304]]
# W2: [[0.14947392 0.19894784]
#  [0.24901674 0.29803348]]
# W3: [[-0.20789484 -0.16077877]
#  [ 0.6432385   0.69392804]]
# b2: [[0.33947845]
#  [0.33033481]]
# b3: [[-0.43136263]
#  [ 0.84291876]]
# ----------------------------------------
# Epoch 5:
# A2: [[0.59069687]
#  [0.59208442]]
# A3: [[0.34313376]
#  [0.83668157]]
# Z2: [[0.36684693]
#  [0.37258899]]
# Z3: [[-0.64936006]
#  [ 1.6337417 ]]
# D2: [[-0.00703225]
#  [-0.00642691]]
# D3: [[ 0.07508601]
#  [-0.02095028]]
# W2: [[0.15017715 0.20035429]
#  [0.24965943 0.29931886]]
# W3: [[-0.29660098 -0.24969328]
#  [ 0.66798902  0.7187367 ]]
# b2: [[0.35354294]
#  [0.34318863]]
# b3: [[-0.58153465]
#  [ 0.88481931]]
# ----------------------------------------
# Epoch 6:
# A2: [[0.5941353 ]
#  [0.59522388]]
# A3: [[0.28774134]
#  [0.84677199]]
# Z2: [[0.38108723]
#  [0.38560349]]
# Z3: [[-0.90637917]
#  [ 1.70950442]]
# D2: [[-0.0070646 ]
#  [-0.00664247]]
# D3: [[ 0.05692205]
#  [-0.01858372]]
# W2: [[0.15088361 0.20176721]
#  [0.25032368 0.30064736]]
# W3: [[-0.36423978 -0.31745601]
#  [ 0.69007151  0.74085964]]
# b2: [[0.36767214]
#  [0.35647357]]
# b3: [[-0.69537875]
#  [ 0.92198675]]
# ----------------------------------------
# Epoch 7:
# A2: [[0.59758029]
#  [0.59846047]]
# A3: [[0.24917332]
#  [0.85541697]]
# Z2: [[0.39539304]
#  [0.39905449]]
# Z3: [[-1.10302614]
#  [ 1.77773509]]
# D2: [[-0.00668158]
#  [-0.00637688]]
# D3: [[ 0.04474597]
#  [-0.01664506]]
# W2: [[0.15155176 0.20310353]
#  [0.25096137 0.30192273]]
# W3: [[-0.4177184  -0.3710134 ]
#  [ 0.70996503  0.76078247]]
# b2: [[0.38103529]
#  [0.36922733]]
# b3: [[-0.7848707 ]
#  [ 0.95527688]]
# ----------------------------------------
# Epoch 8:
# A2: [[0.60082966]
#  [0.60155959]]
# A3: [[0.22114006]
#  [0.86288967]]
# Z2: [[0.40892323]
#  [0.41196767]]
# Z3: [[-1.25903498]
#  [ 1.83950092]]
# D2: [[-0.00620393]
#  [-0.00597618]]
# D3: [[ 0.03636616]
#  [-0.01503856]]
# W2: [[0.15217216 0.20434432]
#  [0.25155898 0.30311797]]
# W3: [[-0.46141814 -0.41476623]
#  [ 0.72803626  0.77887565]]
# b2: [[0.39344315]
#  [0.38117968]]
# b3: [[-0.85760302]
#  [ 0.985354  ]]
# ----------------------------------------
# Epoch 9:
# A2: [[0.60383883]
#  [0.60445662]]
# A3: [[0.19989777]
#  [0.86941169]]
# Z2: [[0.42148619]
#  [0.42406943]]
# Z3: [[-1.38693339]
#  [ 1.8957671 ]]
# D2: [[-0.00573685]
#  [-0.00556141]]
# D3: [[ 0.03037199]
#  [-0.01369099]]
# W2: [[0.15274584 0.20549168]
#  [0.25211513 0.30423025]]
# W3: [[-0.49809772 -0.45148333]
#  [ 0.74457057  0.79542688]]
# b2: [[0.40491685]
#  [0.39230251]]
# b3: [[-0.91834701]
#  [ 1.01273598]]
# ----------------------------------------
# Epoch 10:
# A2: [[0.60661447]
#  [0.60714601]]
# A3: [[0.18322981]
#  [0.87515669]]
# Z2: [[0.43310331]
#  [0.43533129]]
# Z3: [[-1.49461659]
#  [ 1.94734351]]
# D2: [[-0.00531095]
#  [-0.00517237]]
# D3: [[ 0.02592499]
#  [-0.01254749]]
# W2: [[0.15327694 0.20655387]
#  [0.25263236 0.30526473]]
# W3: [[-0.52955067 -0.48296385]
#  [ 0.75979354  0.81066319]]
# b2: [[0.41553874]
#  [0.40264726]]
# b3: [[-0.97019699]
#  [ 1.03783096]]
# ----------------------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given values
A1 = np.array([[0.05], [0.10]])
W2 = np.array([[0.15, 0.20], [0.25, 0.30]])
W3 = np.array([[0.40, 0.45], [0.50, 0.55]])
b2 = np.array([[0.35], [0.35]])
b3 = np.array([[0.60], [0.60]])

# Given R vector
R = np.array([[0.01], [0.99]])

# Learning rate
alpha = 0.5

# Sigmoid activation function and its derivative
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

# Number of epochs
epochs = 20

# Initialize an array to store total errors
errors = np.zeros(epochs)

# Loop through epochs
for epoch in range(epochs):
    # Forward pass calculations
    Z2 = np.dot(W2, A1) + b2
    A2 = sigmoid(Z2)

    Z3 = np.dot(W3, A2) + b3
    A3 = sigmoid(Z3)

    # Calculate Deltas
    D3 = (A3 - R) * sigmoid_derivative(Z3)
    D2 = np.dot(W3.T, D3) * sigmoid_derivative(Z2)

    # Calculate gradients
    grad_W3 = np.dot(D3, A2.T)
    grad_b3 = D3
    grad_W2 = np.dot(D2, A1.T)
    grad_b2 = D2

    # Update weights and biases
    W2 = W2 - alpha * grad_W2
    b2 = b2 - alpha * grad_b2

    W3 = W3 - alpha * grad_W3
    b3 = b3 - alpha * grad_b3

    # Calculate total error and store in array
    total_error = np.sum((A3 - R) ** 2) / 2
    errors[epoch] = total_error

    # Print values for each epoch
    print(f"Epoch {epoch + 1}:")
    print("A2:", A2)
    print("A3:", A3)
    print("Z2:", Z2)
    print("Z3:", Z3)
    print("D2:", D2)
    print("D3:", D3)
    print("W2:", W2)
    print("W3:", W3)
    print("b2:", b2)
    print("b3:", b3)
    print("-" * 40)

# Plot the graph of total errors
plt.figure()
plt.plot(range(1, epochs + 1), errors, '-o')
plt.xlabel('Epochs')
plt.ylabel('Total Error')
plt.title('Total Error vs. Epochs')
plt.grid(True)
plt.show()
# Out:
# Epoch 1:
# A2: [[0.59326999]
#  [0.59688438]]
# A3: [[0.75136507]
#  [0.77292847]]
# Z2: [[0.3775]
#  [0.3925]]
# Z3: [[1.10590597]
#  [1.2249214 ]]
# D2: [[0.00877135]
#  [0.00995425]]
# D3: [[ 0.13849856]
#  [-0.03809824]]
# W2: [[0.14978072 0.19956143]
#  [0.24975114 0.29950229]]
# W3: [[0.35891648 0.40866619]
#  [0.51130127 0.56137012]]
# b2: [[0.34561432]
#  [0.34502287]]
# b3: [[0.53075072]
#  [0.61904912]]
# ----------------------------------------
# Epoch 2:
# A2: [[0.59219805]
#  [0.59567126]]
# A3: [[0.72844176]
#  [0.77837692]]
# Z2: [[0.3730595 ]
#  [0.38746066]]
# Z3: [[0.98673106]
#  [1.25623278]]
# D2: [[0.00781077]
#  [0.00905231]]
# D3: [[ 0.1421181 ]
#  [-0.03650631]]
# W2: [[0.14958545 0.19917089]
#  [0.24952484 0.29904967]]
# W3: [[0.31683545 0.36633835]
#  [0.52211075 0.572243  ]]
# b2: [[0.34170894]
#  [0.34049672]]
# b3: [[0.45969167]
#  [0.63730227]]
# ----------------------------------------
# Epoch 3:
# A2: [[0.59124277]
#  [0.59456704]]
# A3: [[0.70366901]
#  [0.78350896]]
# Z2: [[0.3691053 ]
#  [0.38287793]]
# Z3: [[0.86483105]
#  [1.28623331]]
# D2: [[0.00665593]
#  [0.00794167]]
# D3: [[ 0.14464312]
#  [-0.03502556]]
# W2: [[0.14941905 0.1988381 ]
#  [0.24932629 0.29865259]]
# W3: [[0.27407585 0.32333834]
#  [0.53246506 0.58265552]]
# b2: [[0.33838097]
#  [0.33652588]]
# b3: [[0.38737011]
#  [0.65481506]]
# ----------------------------------------
# Epoch 4:
# A2: [[0.59042818]
#  [0.59359751]]
# A3: [[0.67724182]
#  [0.78835869]]
# Z2: [[0.36573574]
#  [0.37885746]]
# Z3: [[0.74112504]
#  [1.3150603 ]]
# D2: [[0.00533453]
#  [0.00664759]]
# D3: [[ 0.14584928]
#  [-0.0336437 ]]
# W2: [[0.14928569 0.19857137]
#  [0.2491601  0.29832021]]
# W3: [[0.23101909 0.28005045]
#  [0.54239715 0.59264093]]
# b2: [[0.33571371]
#  [0.33320209]]
# b3: [[0.31444547]
#  [0.67163691]]
# ----------------------------------------
# Epoch 5:
# A2: [[0.58977495]
#  [0.5927854 ]]
# A3: [[0.64946868]
#  [0.79295627]]
# Z2: [[0.36303513]
#  [0.37549211]]
# Z3: [[0.61670456]
#  [1.34283806]]
# D2: [[0.00389172]
#  [0.00521358]]
# D3: [[ 0.14558087]
#  [-0.03234997]]
# W2: [[0.14918839 0.19837679]
#  [0.24902976 0.29805953]]
# W3: [[0.18808911 0.23690134]
#  [0.55193676 0.60222923]]
# b2: [[0.33376785]
#  [0.3305953 ]]
# b3: [[0.24165503]
#  [0.68781189]]
# ----------------------------------------
# Epoch 6:
# A2: [[0.5892982 ]
#  [0.59214812]]
# A3: [[0.62076024]
#  [0.79732782]]
# Z2: [[0.36106495]
#  [0.37285274]]
# Z3: [[0.49277629]
#  [1.36967614]]
# D2: [[0.00238625]
#  [0.00369798]]
# D3: [[ 0.14378332]
#  [-0.03113508]]
# W2: [[0.14912874 0.19825747]
#  [0.24893732 0.29787463]]
# W3: [[0.14572348 0.19433083]
#  [0.56111068 0.61144752]]
# b2: [[0.33257473]
#  [0.32874631]]
# b3: [[0.16976337]
#  [0.70337944]]
# ----------------------------------------
# Epoch 7:
# A2: [[0.5890058 ]
#  [0.59169591]]
# A3: [[0.59159915]
#  [0.80149555]]
# Z2: [[0.35985691]
#  [0.37098064]]
# Z3: [[0.37058011]
#  [1.39566788]]
# D2: [[0.00088327]
#  [0.00216692]]
# D3: [[ 0.14051993]
#  [-0.02999114]]
# W2: [[0.14910665 0.19821331]
#  [0.24888314 0.29776628]]
# W3: [[0.10433996 0.1527583 ]
#  [0.56994316 0.62032034]]
# b2: [[0.33213309]
#  [0.32766285]]
# b3: [[0.0995034 ]
#  [0.71837501]]
# ----------------------------------------
# Epoch 8:
# A2: [[0.58889754]
#  [0.59143086]]
# A3: [[0.5624952 ]
#  [0.80547786]]
# Z2: [[0.35940975]
#  [0.36988363]]
# Z3: [[0.25129492]
#  [1.42088973]]
# D2: [[-0.00055471]
#  [ 0.00068517]]
# D3: [[ 0.13596595]
#  [-0.02891153]]
# W2: [[0.14912052 0.19824104]
#  [0.24886601 0.29773203]]
# W3: [[0.06430495 0.11255107]
#  [0.57845612 0.62886992]]
# b2: [[0.33241044]
#  [0.32732026]]
# b3: [[0.03152043]
#  [0.73283077]]
# ----------------------------------------
# Epoch 9:
# A2: [[0.58896553]
#  [0.59134704]]
# A3: [[0.53393539]
#  [0.80928977]]
# Z2: [[0.35969057]
#  [0.36953676]]
# Z3: [[0.13595057]
#  [1.44540186]]
# D2: [[-0.00187604]
#  [-0.0006924 ]]
# D3: [[ 0.13038048]
#  [-0.02789079]]
# W2: [[0.14916742 0.19833485]
#  [0.24888332 0.29776665]]
# W3: [[0.02591015 0.07400101]
#  [0.58666948 0.63711649]]
# b2: [[0.33334846]
#  [0.32766646]]
# b3: [[-0.03366981]
#  [ 0.74677617]]
# ----------------------------------------
# Epoch 10:
# A2: [[0.58919543]
#  [0.59143174]]
# A3: [[0.50634038]
#  [0.81294337]]
# Z2: [[0.36064032]
#  [0.36988729]]
# Z3: [[0.02536288]
#  [1.46925006]]
# D2: [[-0.0030452]
#  [-0.0019266]]
# D3: [[ 0.12406514]
#  [-0.02692437]]
# W2: [[0.14924355 0.19848711]
#  [0.24893149 0.29786298]]
# W3: [[-0.01063916  0.03731298]
#  [ 0.59460134  0.64507846]]
# b2: [[0.33487106]
#  [0.32862976]]
# b3: [[-0.09570238]
#  [ 0.76023835]]
# ----------------------------------------
# Epoch 11:
# A2: [[0.58956852]
#  [0.5916674 ]]
# A3: [[0.48003611]
#  [0.81644849]]
# Z2: [[0.36218195]
#  [0.37086263]]
# Z3: [[-0.07989802]
#  [ 1.49246848]]
# D2: [[-0.00404414]
#  [-0.00299578]]
# D3: [[ 0.11732169]
#  [-0.02600849]]
# W2: [[0.14934466 0.19868931]
#  [0.24900638 0.29801276]]
# W3: [[-0.04522375  0.00260527]
#  [ 0.60226823  0.65277264]]
# b2: [[0.33689313]
#  [0.33012765]]
# b3: [[-0.15436323]
#  [ 0.7732426 ]]
# ----------------------------------------
# Epoch 12:
# A2: [[0.59006384]
#  [0.59203376]]
# A3: [[0.45524369]
#  [0.81981325]]
# Z2: [[0.3642293 ]
#  [0.37237924]]
# Z3: [[-0.17950572]
#  [ 1.51508275]]
# D2: [[-0.00487031]
#  [-0.00389418]]
# D3: [[ 0.11041904]
#  [-0.0251399 ]]
# W2: [[0.14946641 0.19893283]
#  [0.24910374 0.29820747]]
# W3: [[-0.07780089 -0.03008063]
#  [ 0.60968531  0.66021448]]
# b2: [[0.33932829]
#  [0.33207474]]
# b3: [[-0.20957275]
#  [ 0.78581255]]
# ----------------------------------------
# Epoch 13:
# A2: [[0.59066011]
#  [0.59250983]]
# A3: [[0.43208493]
#  [0.82304464]]
# Z2: [[0.36669489]
#  [0.37435067]]
# Z3: [[-0.2733497 ]
#  [ 1.53711291]]
# D2: [[-0.0055327 ]
#  [-0.00462825]]
# D3: [[ 0.10357439]
#  [-0.02431574]]
# W2: [[0.14960473 0.19920946]
#  [0.24921944 0.29843889]]
# W3: [[-0.10838952 -0.06076505]
#  [ 0.61686648  0.66741814]]
# b2: [[0.34209464]
#  [0.33438886]]
# b3: [[-0.26135994]
#  [ 0.79797042]]
# ----------------------------------------
# Epoch 14:
# A2: [[0.59133714]
#  [0.59307542]]
# A3: [[0.41059821]
#  [0.82614889]]
# Z2: [[0.36949582]
#  [0.37669372]]
# Z3: [[-0.36149295]
#  [ 1.55857577]]
# D2: [[-0.0060475 ]
#  [-0.00521232]]
# D3: [[ 0.0969477 ]
#  [-0.02353343]]
# W2: [[0.14975592 0.19951184]
#  [0.24934975 0.2986995 ]]
# W3: [[-0.13705391 -0.0895137 ]
#  [ 0.62382457  0.67439669]]
# b2: [[0.34511839]
#  [0.33699502]]
# b3: [[-0.30983379]
#  [ 0.80973713]]
# ----------------------------------------
# Epoch 15:
# A2: [[0.59207678]
#  [0.59371209]]
# A3: [[0.39075836]
#  [0.8291318 ]]
# Z2: [[0.37255737]
#  [0.37933245]]
# Z3: [[-0.44412559]
#  [ 1.57948664]]
# D2: [[-0.0064343 ]
#  [-0.00566474]]
# D3: [[ 0.09064572]
#  [-0.02279056]]
# W2: [[0.14991678 0.19983355]
#  [0.24949137 0.29898274]]
# W3: [[-0.16388852 -0.11642243]
#  [ 0.63057145  0.6811622 ]]
# b2: [[0.34833554]
#  [0.33982739]]
# b3: [[-0.35515665]
#  [ 0.82113241]]
# ----------------------------------------
# Epoch 16:
# A2: [[0.59286327]
#  [0.59440366]]
# A3: [[0.3724964 ]
#  [0.83199887]]
# Z2: [[0.37581473]
#  [0.38220023]]
# Z3: [[-0.52152205]
#  [ 1.59986037]]
# D2: [[-0.00671329]
#  [-0.00600501]]
# D3: [[ 0.08473093]
#  [-0.02208488]]
# W2: [[0.15008461 0.20016922]
#  [0.24964149 0.29928299]]
# W3: [[-0.18900545 -0.14160462]
#  [ 0.63711811  0.68772587]]
# b2: [[0.35169218]
#  [0.34282989]]
# b3: [[-0.39752212]
#  [ 0.83217486]]
# ----------------------------------------
# Epoch 17:
# A2: [[0.59368335]
#  [0.59513637]]
# A3: [[0.35571632]
#  [0.8347554 ]]
# Z2: [[0.37921334]
#  [0.38524027]]
# Z3: [[-0.59400556]
#  [ 1.61971195]]
# D2: [[-0.0069035 ]
#  [-0.00625185]]
# D3: [[ 0.07923203]
#  [-0.02141426]]
# W2: [[0.1502572  0.20051439]
#  [0.24979779 0.29959558]]
# W3: [[-0.21252482 -0.16518155]
#  [ 0.64347475  0.69409807]]
# b2: [[0.35514393]
#  [0.34595582]]
# b3: [[-0.43713813]
#  [ 0.84288198]]
# ----------------------------------------
# Epoch 18:
# A2: [[0.59452613]
#  [0.59589874]]
# A3: [[0.34030818]
#  [0.83740654]]
# Z2: [[0.38270823]
#  [0.38840527]]
# Z3: [[-0.66192117]
#  [ 1.63905671]]
# D2: [[-0.00702192]
#  [-0.00642219]]
# D3: [[ 0.0741537 ]
#  [-0.02077664]]
# W2: [[0.15043274 0.20086549]
#  [0.24995835 0.29991669]]
# W3: [[-0.23456798 -0.1872756 ]
#  [ 0.64965088  0.70028846]]
# b2: [[0.35865489]
#  [0.34916691]]
# b3: [[-0.47421498]
#  [ 0.8532703 ]]
# ----------------------------------------
# Epoch 19:
# A2: [[0.59538279]
#  [0.5966814 ]]
# A3: [[0.32615737]
#  [0.83995729]]
# Z2: [[0.38626308]
#  [0.3916565 ]]
# Z3: [[-0.72561658]
#  [ 1.65791036]]
# D2: [[-0.0070831 ]
#  [-0.00653075]]
# D3: [[ 0.06948467]
#  [-0.0201701 ]]
# W2: [[0.15060982 0.20121964]
#  [0.25012161 0.30024323]]
# W3: [[-0.25525296 -0.2080057 ]
#  [ 0.65565535  0.70630602]]
# b2: [[0.36219644]
#  [0.35243229]]
# b3: [[-0.50895732]
#  [ 0.86335535]]
# ----------------------------------------
# Epoch 20:
# A2: [[0.59624632]
#  [0.59747679]]
# A3: [[0.31315088]
#  [0.84241249]]
# Z2: [[0.3898489 ]
#  [0.39496269]]
# Z3: [[-0.78542954]
#  [ 1.6762889 ]]
# D2: [[-0.00709923]
#  [-0.00658996]]
# D3: [[ 0.06520394]
#  [-0.01959279]]
# W2: [[0.1507873  0.20157461]
#  [0.25028636 0.30057273]]
# W3: [[-0.27469177 -0.22748462]
#  [ 0.66149641  0.71215914]]
# b2: [[0.36574606]
#  [0.35572727]]
# b3: [[-0.54155929]
#  [ 0.87315175]]
# ----------------------------------------
